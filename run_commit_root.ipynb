# %%
import subprocess
from pathlib import Path
repo_root = Path('/workspaces/M2.-Despliegue-multientorno')
result = subprocess.run(['python3', str(repo_root / 'commit_root_files.py')], capture_output=True, text=True)
print(result.stdout)
print(result.stderr)
# Out:
# Checking out develop...
#
#
# [main b08df2f] Add root site files and config for develop
#  4 files changed, 121 insertions(+)
#  create mode 100644 app.js
#  create mode 100644 config.js
#  create mode 100644 index.html
#  create mode 100644 style.css
#
#
# branch 'develop' set up to track 'origin/develop'.
#
# Everything up-to-date
#
#
# Checking out staging...
#
#
# [staging fe1677d] Add root site files and config for staging
#  4 files changed, 121 insertions(+)
#  create mode 100644 app.js
#  create mode 100644 config.js
#  create mode 100644 index.html
#  create mode 100644 style.css
#
#
# branch 'staging' set up to track 'origin/staging'.
#
# To https://github.com/JBulian09/M2.-Despliegue-multientorno
#    fcdef48..fe1677d  staging -> staging
#
#
# Checking out main...
#
#
# [main b60d6ff] Add root site files and config for main
#  1 file changed, 6 insertions(+), 6 deletions(-)
#
#
# branch 'main' set up to track 'origin/main'.
#
# ...
